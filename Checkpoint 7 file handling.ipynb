# %%
file = open("python.txt", 'r')
all_lines = file.readlines() #Question1
first_n_lines = file.read(n) #Question2
last_n_lines = all_lines(-n:) #Question3
words_from_file = file.split() #Question4
number_of_words = len(words_from_file) #Question4 
#The bonus question is just question 3 repeated lol :)
